# %% [markdown]
# # Importing libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Import dataframe 2015
df_2015 = pd.read_csv(r'C:\Users\kater\Desktop\DATA IMMERSION\ACHIEVEMENT 6\archive\2015.csv', index_col= False)

# %%
#Import dataframe 2016
df_2016 = pd.read_csv(r'C:\Users\kater\Desktop\DATA IMMERSION\ACHIEVEMENT 6\archive\2016.csv', index_col=False)

# %%
#Import dataframe 2017
df_2017 = pd.read_csv(r'C:\Users\kater\Desktop\DATA IMMERSION\ACHIEVEMENT 6\archive\2017.csv', index_col = False)

# %%
#Import dataframe 2018
df_2018 = pd.read_csv(r'C:\Users\kater\Desktop\DATA IMMERSION\ACHIEVEMENT 6\archive\2018.csv', index_col = False)

# %%
#Import dataframe 2019
df_2019 = pd.read_csv(r'C:\Users\kater\Desktop\DATA IMMERSION\ACHIEVEMENT 6\archive\2019.csv', index_col = False)

# %%
#Creating path
path = r'C:\Users\kater\Desktop'

# %%
path
# Out:
# 'C:\\Users\\kater\\Desktop'

# %% [markdown]
# # Data Wrangling

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2015.shape
# Out:
# (158, 12)

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df_2015.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#Descriptive statistics
df_2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#Renaming column Economy(GDP per Capita)
df_2015.rename(columns = {'Economy (GDP per Capita)' : 'GDP per Capita'}, inplace = True)

# %%
#Renaming column Health(Life Expectancy)
df_2015.rename(columns = {'Health (Life Expectancy)' : 'Life Expectancy'}, inplace = True)

# %%
#Renaming column Trust(Goverment Corruption)
df_2015.rename(columns = {'Trust (Government Corruption)' : 'Perceptions of Goverment Corruption'}, inplace = True)

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  GDP per Capita   Family  Life Expectancy  Freedom  \
# 0         0.03411         1.39651  1.34951          0.94143  0.66557
# 1         0.04884         1.30232  1.40223          0.94784  0.62877
# 2         0.03328         1.32548  1.36058          0.87464  0.64938
# 3         0.03880         1.45900  1.33095          0.88521  0.66973
# 4         0.03553         1.32629  1.32261          0.90563  0.63297
#
#    Perceptions of Goverment Corruption  Generosity  Dystopia Residual
# 0                              0.41978     0.29678            2.51738
# ...

# %%
#Checking missing values
df_2015.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Happiness Rank                         0
# Happiness Score                        0
# Standard Error                         0
# GDP per Capita                         0
# Family                                 0
# Life Expectancy                        0
# Freedom                                0
# Perceptions of Goverment Corruption    0
# Generosity                             0
# Dystopia Residual                      0
# dtype: int64

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2016.shape
# Out:
# (157, 13)

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
df_2016.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#Descriptive statistics
df_2016.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
#Renaming column Economy(GDP per Capita)
df_2016.rename(columns = {'Economy (GDP per Capita)' : 'GDP per Capita'}, inplace = True)

# %%
#Renaming column Health(Life Expectancy)
df_2016.rename(columns = {'Health (Life Expectancy)' : 'Life Expectancy'}, inplace = True)

# %%
#Renaming column Trust(Goverment Corruption)
df_2016.rename(columns = {'Trust (Government Corruption)' : 'Perceptions of Goverment Corruption'}, inplace = True)

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  GDP per Capita  \
# 0                      7.460                      7.592         1.44178
# 1                      7.428                      7.590         1.52733
# 2                      7.333                      7.669         1.42666
# 3                      7.421                      7.575         1.57744
# 4                      7.351                      7.475         1.40598
#
#     Family  Life Expectancy  Freedom  Perceptions of Goverment Corruption  \
# ...

# %%
#Checking missing values
df_2015.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Happiness Rank                         0
# Happiness Score                        0
# Standard Error                         0
# GDP per Capita                         0
# Family                                 0
# Life Expectancy                        0
# Freedom                                0
# Perceptions of Goverment Corruption    0
# Generosity                             0
# Dystopia Residual                      0
# dtype: int64

# %%
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_2017.shape
# Out:
# (155, 12)

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
df_2017.dtypes
# Out:
# Country                           object
# Happiness.Rank                     int64
# Happiness.Score                  float64
# Whisker.high                     float64
# Whisker.low                      float64
# Economy..GDP.per.Capita.         float64
# Family                           float64
# Health..Life.Expectancy.         float64
# Freedom                          float64
# Generosity                       float64
# Trust..Government.Corruption.    float64
# Dystopia.Residual                float64
# dtype: object

# %%
#Descriptive statistics
df_2017.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %%
#Renaming column Happiness.Rank
df_2017.rename(columns = {'Happiness.Rank' : 'Happiness Rank'}, inplace = True)

# %%
#Renaming column Happiness.Score
df_2017.rename(columns = {'Happiness.Score' : 'Happiness Score'}, inplace = True)

# %%
#Renaming column Whisker.high
df_2017.rename(columns = {'Whisker.high' : 'Whisker high'}, inplace = True)

# %%
#Renaming column Whisker.low
df_2017.rename(columns = {'Whisker.low' : 'Whisker low'}, inplace = True)

# %%
#Renaming column Economy..GDP.per.Capita.
df_2017.rename(columns = {'Economy..GDP.per.Capita.' : 'GDP per Capita'}, inplace = True)

# %%
#Renaming column Health..Life.Expectancy.
df_2017.rename(columns = {'Health..Life.Expectancy.' : 'Life Expectancy'}, inplace = True)

# %%
#Renaming column Trust..Government.Corruption.
df_2017.rename(columns = {'Trust..Government.Corruption.' : 'Perceptions of Goverment Corruption'}, inplace = True)

# %%
#Renaming column Dystopia.Residual
df_2017.rename(columns = {'Dystopia.Residual' : 'Dystopia Residual'}, inplace = True)

# %%
df_2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Whisker high  Whisker low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    GDP per Capita    Family  Life Expectancy   Freedom  Generosity  \
# 0        1.616463  1.533524         0.796667  0.635423    0.362012
# 1        1.482383  1.551122         0.792566  0.626007    0.355280
# 2        1.480633  1.610574         0.833552  0.627163    0.475540
# 3        1.564980  1.516912         0.858131  0.620071    0.290549
# 4        1.443572  1.540247         0.809158  0.617951    0.245483
#
#    Perceptions of Goverment Corruption  Dystopia Residual
# ...

# %%
#Checking missing values
df_2017.isnull().sum()
# Out:
# Country                                0
# Happiness Rank                         0
# Happiness Score                        0
# Whisker high                           0
# Whisker low                            0
# GDP per Capita                         0
# Family                                 0
# Life Expectancy                        0
# Freedom                                0
# Generosity                             0
# Perceptions of Goverment Corruption    0
# Dystopia Residual                      0
# dtype: int64

# %%
df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
df_2018.shape
# Out:
# (156, 9)

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
#Descriptive statistics
df_2018.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
#Renaming column Overall rank
df_2018.rename(columns = {'Overall rank' : 'Happiness Rank'}, inplace = True)

# %%
#Renaming column Country or region
df_2018.rename(columns = {'Country or region' : 'Country'}, inplace = True)

# %%
#Renaming column Score
df_2018.rename(columns = {'Score' : 'Happiness Score'}, inplace = True)

# %%
#Renaming column GDP per capita
df_2018.rename(columns = {'GDP per capita' : 'GDP per Capita'}, inplace = True)

# %%
#Renaming column Social support
df_2018.rename(columns = {'Social support' : 'Family'}, inplace = True)

# %%
#Renaming column Healthy life expectancy
df_2018.rename(columns = {'Healthy life expectancy' : 'Life expectancy'}, inplace = True)

# %%
#Renaming column Freedom to make life choices
df_2018.rename(columns = {'Freedom to make life choices' : 'Freedom'}, inplace = True)

# %%
#Renaming column Perceptions of corruption
df_2018.rename(columns = {'Perceptions of corruption ' : 'Perceptions of Goverment Corruption'}, inplace = True)

# %%
df_2018.head()
# Out:
#    Happiness Rank      Country  Happiness Score  GDP per Capita  Family  \
# 0               1      Finland            7.632           1.305   1.592
# 1               2       Norway            7.594           1.456   1.582
# 2               3      Denmark            7.555           1.351   1.590
# 3               4      Iceland            7.495           1.343   1.644
# 4               5  Switzerland            7.487           1.420   1.549
#
#    Life expectancy  Freedom  Generosity  Perceptions of corruption
# 0            0.874    0.681       0.202                      0.393
# 1            0.861    0.686       0.286                      0.340
# 2            0.868    0.683       0.284                      0.408
# 3            0.914    0.677       0.353                      0.138
# 4            0.927    0.660       0.256                      0.357

# %%
#Checking missing values
df_2018.isnull().sum()
# Out:
# Happiness Rank               0
# Country                      0
# Happiness Score              0
# GDP per Capita               0
# Family                       0
# Life expectancy              0
# Freedom                      0
# Generosity                   0
# Perceptions of corruption    1
# dtype: int64

# %%
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df_2019.shape
# Out:
# (156, 9)

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
#Descriptive statistics
df_2019.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
#Renaming column Overall rank
df_2019.rename(columns = {'Overall rank' : 'Happiness Rank'}, inplace = True)

# %%
#Renaming column Country or region
df_2019.rename(columns = {'Country or region' : 'Country'}, inplace = True)

# %%
#Renaming column Score
df_2019.rename(columns = {'Score' : 'Happiness Score'}, inplace = True)

# %%
#Renaming column Social support
df_2019.rename(columns = {'Social support' : 'Family'}, inplace = True)

# %%
#Renaming column Healthy life expectancy
df_2019.rename(columns = {'Healthy life expectancy' : 'Life expectancy'}, inplace = True)

# %%
#Renaming column Freedom to make life choices
df_2019.rename(columns = {'Freedom to make life choices' : 'Freedom'}, inplace = True)

# %%
#Renaming column Perceptions of corruption
df_2019.rename(columns = {'Perceptions of corruption' : 'Perceptions of Goverment Corruption'}, inplace = True)

# %%
df_2019.head()
# Out:
#    Happiness Rank      Country  Happiness Score  GDP per capita  Family  \
# 0               1      Finland            7.769           1.340   1.587
# 1               2      Denmark            7.600           1.383   1.573
# 2               3       Norway            7.554           1.488   1.582
# 3               4      Iceland            7.494           1.380   1.624
# 4               5  Netherlands            7.488           1.396   1.522
#
#    Life expectancy  Freedom  Generosity  Perceptions of Goverment Corruption
# 0            0.986    0.596       0.153                                0.393
# 1            0.996    0.592       0.252                                0.410
# 2            1.028    0.603       0.271                                0.341
# 3            1.026    0.591       0.354                                0.118
# 4            0.999    0.557       0.322                                0.298

# %%
#Checking missing values
df_2019.isnull().sum()
# Out:
# Happiness Rank                         0
# Country                                0
# Happiness Score                        0
# GDP per capita                         0
# Family                                 0
# Life expectancy                        0
# Freedom                                0
# Generosity                             0
# Perceptions of Goverment Corruption    0
# dtype: int64

# %% [markdown]
# # Exporting Data

# %%
df_2015.to_csv(os.path.join(path, 'DATA IMMERSION', 'ACHIEVEMENT 6', 'archive','2015_clean.csv'))

# %%
df_2016.to_csv(os.path.join(path, 'DATA IMMERSION', 'ACHIEVEMENT 6', 'archive','2016_clean.csv'))

# %%
df_2017.to_csv(os.path.join(path, 'DATA IMMERSION', 'ACHIEVEMENT 6', 'archive','2017_clean.csv'))

# %%
df_2018.to_csv(os.path.join(path, 'DATA IMMERSION', 'ACHIEVEMENT 6', 'archive','2018_clean.csv'))

# %%
df_2019.to_csv(os.path.join(path, 'DATA IMMERSION', 'ACHIEVEMENT 6', 'archive','2019_clean.csv'))
